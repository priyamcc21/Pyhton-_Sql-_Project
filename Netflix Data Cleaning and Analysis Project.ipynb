# %%
# End to End ETL Project
# ETL -> Extract, Transform, Load
# Kaggle api -> Download Dataset -> Python
# Data cleaning and Processing -> Python
# Load data to sql server
# and then do data analysis using sql.

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
print(data)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Load the data into sql server using replace option.
import mysql.connector
import sqlalchemy
import pandas as pd
import pymysql
import sys

# %%
# Connects to the MySQL database sys.
engine = create_engine(
"mysql+pymysql://root:Mysql@127.0.0.1:3306/sys"
    
)
# username - root                       
# password - Mysql
# hostname - 127.0.0.1  -->localhost
# port - 3306
# database - sys

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connection string
engine =  create_engine(
    "mssql+pyodbc://@LAPTOP-JARF041B/namestesql?"
    "driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# %%
# Go to sql server
# right click on that select properties
# This is my server name LAPTOP-JARF041B

# %%
# Load the data into sql server using append option
data.to_sql('netflix_raw', con=engine, index = False, if_exists = 'append')
# Out:
# -1

# %%
# Count total records
len(data)
# Out:
# 8807

# %%
# Filter data for show_id s5023
data[data.show_id== 's5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#      date_added  release_year rating duration  \
# 5022  28-Feb-18          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
# show length of each show_id
data.show_id.str.len()
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 8802    5
# 8803    5
# 8804    5
# 8805    5
# 8806    5
# Name: show_id, Length: 8807, dtype: int64

# %%
# Show maximum length of show_id
max(data.show_id.str.len())
# Out:
# 5

# %%
# Maximum length of strings in 'type' column
max(data.type.str.len())
# Out:
# 7

# %%
# Maximum length of strings in 'title' column
max(data.title.str.len())
# Out:
# 104

# %%
# Maximum length of strings in 'director' column
max(data.director.str.len())
# Out:
# 208.0

# %%
# Maximum length of strings in 'cast' column , dropping missing values.
max(data.cast.dropna().str.len())                          
                                                  # Here, cast has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 771

# %%
# Maximum length of strings in 'country' column , dropping missing values.
max(data.country.dropna().str.len())                          
                                                  # Here, country has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 123

# %%
# Maximum length of strings in 'date_added' column , dropping missing values.
max(data.date_added.dropna().str.len())                          
                                                  # Here, date_added has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 19

# %%
# Maximum length of strings in 'rating' column , dropping missing values.
max(data.rating.dropna().str.len())                          
                                                  # Here, rating has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 8

# %%
# Maximum length of strings in 'duration' column , dropping missing values.
max(data.duration.dropna().str.len())                          
                                                  # Here, duration has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 10

# %%
# Maximum length of strings in 'listed_in' column , dropping missing values.
max(data.listed_in.dropna().str.len())                          
                                                  # Here, listed_in has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 79

# %%
# Maximum length of strings in 'description' column , dropping missing values.
max(data.description.dropna().str.len())                          
                                                  # Here, description has null values
                                                  # we will drop null values here, use dropna() for that.
# Out:
# 248

# %%
# I worked on a Netflix data cleaning project where I loaded data from csv into Sql Server using Python.
# I faced an issue where some movie titles shows as question marks because the table was created using varchar.
# I fixed this by dropping the old table.
# Then, I create the table again using nvarchar data type ,  then I run python codes again to load this data in sql. 
# After that, I checked the data and looked for duplicates using Sql queries.
